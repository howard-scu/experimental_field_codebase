# %%
# !pip install pydicom

# %%
import pydicom

# %%
dcm = pydicom.read_file("train/1.dcm")

# %%
ds = pydicom.dcmread("train/1.dcm")

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(ds.pixel_array)
plt.show()

# %%
import numpy as np

# %%
np.max(ds.pixel_array)
# Out:
# 520

# %%
train = []

# %%
for i in range(1,41,1):
    fname = "train/%d.dcm"% (i)
    ds = pydicom.dcmread(fname)
# Out:
# train/1.dcm
# train/2.dcm
# train/3.dcm
# train/4.dcm
# train/5.dcm
# train/6.dcm
# train/7.dcm
# train/8.dcm
# train/9.dcm
# train/10.dcm
# train/11.dcm
# train/12.dcm
# train/13.dcm
# train/14.dcm
# train/15.dcm
# train/16.dcm
# train/17.dcm
# train/18.dcm
# train/19.dcm
# train/20.dcm
# train/21.dcm
# train/22.dcm
# train/23.dcm
# train/24.dcm
# train/25.dcm
# train/26.dcm
# train/27.dcm
# train/28.dcm
# train/29.dcm
# train/30.dcm
# train/31.dcm
# train/32.dcm
# train/33.dcm
# train/34.dcm
# train/35.dcm
# train/36.dcm
# train/37.dcm
# train/38.dcm
# train/39.dcm
# train/40.dcm
